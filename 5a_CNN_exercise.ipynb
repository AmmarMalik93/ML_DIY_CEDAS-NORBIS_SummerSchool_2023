# %% [markdown]
# # **Introduction**
# In this exercise you will try to do image classification on _CIFAR10_ dataset. It contains 60,000 color images in 10 classes, with 6,000 images in each class. The dataset is divided into 50,000 training images and 10,000 testing images. The classes are mutually exclusive and there is no overlap between them.

# %% [markdown]
# # **Importing libraries**

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# # **Download and prepare the CIFAR10 dataset**

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
print("Train images shape:",train_images.shape)
print("Train labels shape:",train_labels.shape)
print("\n")
print("Test images shape:",test_images.shape)
print("Test labels shape:",test_labels.shape)

# %% [markdown]
# # **Visualize the training data**

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays,
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %% [markdown]
# # **Split training set in train and validation sets**

# %%
train_images, train_labels, val_images, val_labels = train_test_split()

# %%
# Print the shapes of new train and validation images and labels

# %% [markdown]
# # **Creating CNN Model**

# %%
model = models.Sequential()
# Create your own model below
model.add()

# %%
# Print the summary of your model
model.summary()

# %% [markdown]
# # **Training the model**

# %%
batch_size =
epochs =

model.compile()

history = model.fit()

# %% [markdown]
# # **Display training and validation accuracy and loss**

# %%
# Your code here

# %% [markdown]
# # **Performance on Test data**

# %%
# Your code here

# %% [markdown]
# # **Visualizing incorrect predictions**

# %%
# Your code here
